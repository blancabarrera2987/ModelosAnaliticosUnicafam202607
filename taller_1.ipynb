# %% [markdown]
# <a href="https://colab.research.google.com/github/blancabarrera2987/ModelosAnaliticosUnicafam202607/blob/main/taller_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TALLER 1**
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: BLANCA BARRERA FLOREZ

# %% [markdown]
# **OPERACIONES MATEMATICOS**

# %%
# 1. DECLARA DOS VARIABLES A Y B CON LOS VALORES 10 Y 3

a=10
b=3

# %%
# 2. CALCULAR LA SUMA DE A Y B

print(a+b)
# Out:
# 13

# %%
# 3. CALCULA LA RESTA DE A Y B

print(a-b)
# Out:
# 7

# %%
# 4. CALCULA LA MULTIPLICACION DE A Y B

print(a*b)
# Out:
# 30

# %%
# 5. CALCULA LA DIVISION DE A Y B

print(a/b)
# Out:
# 3.3333333333333335

# %%
# 6. CALCULA EL MODULO DE A Y B

print(a%b)
# Out:
# 1

# %%
# 7. CALCULA LA POTENCIA DE ELEVADO AB

print(b**2)
# Out:
# 9

# %%
# 8. CALCULA LA DIVISION ENTRA DE A ENTRE B

print(a//b)
# Out:
# 3

# %% [markdown]
# **VALORES DE CADENA**

# %%
# 1. Declara una cadena llamada saludo con el valor "Hola, mundo!".
saludo = "Hola, mundo!"

print(saludo)
# Out:
# Hola, mundo!

# %%
# 2. muestra el primer carácter de la cadena saludo

print(saludo[0])
# Out:
# H

# %%
# 3. muestra los últimos 5 caracteres de la cadena saludo

print(saludo[5:18])
# Out:
#  mundo!

# %%
# 4. Concatenar la cadena saludo con otra cadena

palabra1="hola"
palabra2="mundo"
palabra3="¿cómo estás?"

print(palabra1+", "+palabra2+", "+palabra3)
# Out:
# hola, mundo, ¿cómo estás?

# %%
cadena="hola, mundo, ¿cómo estás?"
print(cadena)
# Out:
# hola, mundo, ¿cómo estás?

# %%
# 5. Convierte la cadena saludo_completo a mayúsculas y asígnala a una variable

print(cadena.upper())
# Out:
# HOLA, MUNDO, ¿CÓMO ESTÁS?

# %%
# 6. Reemplaza la palabra "mundo" en saludo_completo por "Python"

saludo_reemplazo = cadena.replace("mundo", "Python")
print(saludo_reemplazo)
# Out:
# hola, Python, ¿cómo estás?
